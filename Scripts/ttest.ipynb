# %% [markdown]
# 20世纪初期，英国数学家威廉戈塞(William Gosset)指出，样本统计量的抽样分布，特别是在小样本条件下的抽样分布，并不完全服从正态分布，而是服从与正态分布相似的t分布。当样本容量大于30，而且总体标准差未知时，可以使用t分布。一般来说，t分布与标准正态分布相同，也是对称的，但更平缓一些。不同的样本容量有不同的t分布，随着样本容量的增加，t分布的形状由平缓逐渐变得接近正态分布的形状。确切来说，t分布的曲线形态与自由度df密切相关，t分布的自由度大小是样本容量n-1，即df=n-1。

# %%
#使用Python描述t分布与正态分布之间的关系
import numpy as np
from scipy.stats import norm
from scipy.stats import t
import matplotlib.pyplot as plt

#设置背景
from matplotlib import style
style.use('ggplot')

#绘制t分布曲线
x =  np.linspace(-3, 3, 100)
plt.plot(x, t.pdf(x,1), label='df=1')
plt.plot(x, t.pdf(x,2), label='df=2')
plt.plot(x, t.pdf(x,100), label='df=100')
plt.plot(x[::5], norm.pdf(x[::5]),'kx', label='normal')
plt.legend()
plt.show()
